# %% [markdown]
# # Importing Python Libraries

# %%
import requests
import json
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('database.sqlite')
cur = conn.cursor()

# %%
cur.execute("""SELECT Match_ID, TeamName, Unique_Team_ID, HomeTeam, AwayTeam, Date, Season, Div, 
                FTHG AS HomeTeamGoals, FTAG AS AwayTeamGoals, FTR AS Winners
                FROM Matches
                JOIN Teams_in_Matches
                USING (Match_ID)
                JOIN Unique_Teams
                USING (Unique_Team_ID)
                WHERE Season = 2011
                ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df.head()
# Out:
#    Match_ID       TeamName  Unique_Team_ID   HomeTeam       AwayTeam  \
# 0      1092  Bayern Munich               1   Nurnberg  Bayern Munich
# 1      1092       Nurnberg              22   Nurnberg  Bayern Munich
# 2      1093  Bayern Munich               1  Stuttgart  Bayern Munich
# 3      1093      Stuttgart              17  Stuttgart  Bayern Munich
# 4      1094  Bayern Munich               1  Wolfsburg  Bayern Munich
#
#          Date  Season Div  HomeTeamGoals  AwayTeamGoals Winners
# 0  2012-03-31    2011  D1              0              1       A
# 1  2012-03-31    2011  D1              0              1       A
# 2  2011-12-11    2011  D1              1              2       A
# 3  2011-12-11    2011  D1              1              2       A
# 4  2011-08-13    2011  D1              0              1       A

# %%
for i, row in df.iterrows():
    if row.TeamName == row.AwayTeam:
        if row.Winners == 'A':
            df.loc[i, 'Result'] = 'W'
        if row.Winners == 'D':
            df.loc[i, 'Result'] = 'D'
        if row.Winners == 'H':
            df.loc[i, 'Result'] = 'L'
    else:
        if row.Winners == 'H':
            df.loc[i, 'Result'] = 'W'
        if row.Winners == 'D':
            df.loc[i, 'Result'] = 'D'
        if row.Winners == 'A':
            df.loc[i, 'Result'] = 'L'

# %%
df.head()
# Out:
#    Match_ID       TeamName  Unique_Team_ID   HomeTeam       AwayTeam  \
# 0      1092  Bayern Munich               1   Nurnberg  Bayern Munich
# 1      1092       Nurnberg              22   Nurnberg  Bayern Munich
# 2      1093  Bayern Munich               1  Stuttgart  Bayern Munich
# 3      1093      Stuttgart              17  Stuttgart  Bayern Munich
# 4      1094  Bayern Munich               1  Wolfsburg  Bayern Munich
#
#          Date  Season Div  HomeTeamGoals  AwayTeamGoals Winners Result
# 0  2012-03-31    2011  D1              0              1       A      W
# 1  2012-03-31    2011  D1              0              1       A      L
# 2  2011-12-11    2011  D1              1              2       A      W
# 3  2011-12-11    2011  D1              1              2       A      L
# 4  2011-08-13    2011  D1              0              1       A      W

# %%
for i, row in df.iterrows():
    if row.TeamName == row.AwayTeam:
        df.loc[i, 'GoalsScored'] = df.loc[i, 'AwayTeamGoals']
    elif row.TeamName == row.HomeTeam:
        df.loc[i, 'GoalsScored'] = df.loc[i, 'HomeTeamGoals']

# %%
df.head()
# Out:
#    Match_ID       TeamName  Unique_Team_ID   HomeTeam       AwayTeam  \
# 0      1092  Bayern Munich               1   Nurnberg  Bayern Munich
# 1      1092       Nurnberg              22   Nurnberg  Bayern Munich
# 2      1093  Bayern Munich               1  Stuttgart  Bayern Munich
# 3      1093      Stuttgart              17  Stuttgart  Bayern Munich
# 4      1094  Bayern Munich               1  Wolfsburg  Bayern Munich
#
#          Date  Season Div  HomeTeamGoals  AwayTeamGoals Winners Result  \
# 0  2012-03-31    2011  D1              0              1       A      W
# 1  2012-03-31    2011  D1              0              1       A      L
# 2  2011-12-11    2011  D1              1              2       A      W
# 3  2011-12-11    2011  D1              1              2       A      L
# 4  2011-08-13    2011  D1              0              1       A      W
#
#    GoalsScored
# 0          1.0
# 1          0.0
# 2          2.0
# 3          1.0
# 4          1.0

# %%
total_goals_scored = df.pivot_table(index = 'TeamName', aggfunc='sum')
total_goals_scored = total_goals_scored.rename(columns={"GoalsScored":"Total Goals Scored (2011 Season)"})
total_goals_scored = total_goals_scored.drop(columns = ['AwayTeamGoals','HomeTeamGoals','Match_ID','Season','Unique_Team_ID'])
total_goals_scored.head(20)
# Out:
#                     Total Goals Scored (2011 Season)
# TeamName
# Aachen                                          30.0
# Arsenal                                         74.0
# Aston Villa                                     37.0
# Augsburg                                        36.0
# Bayern Munich                                   77.0
# Blackburn                                       48.0
# Bochum                                          41.0
# Bolton                                          46.0
# Braunschweig                                    37.0
# Chelsea                                         65.0
# Cottbus                                         30.0
# Dortmund                                        80.0
# Dresden                                         50.0
# Duisburg                                        42.0
# Ein Frankfurt                                   76.0
# Erzgebirge Aue                                  31.0
# Everton                                         50.0
# FC Koln                                         39.0
# Fortuna Dusseldorf                              64.0
# Frankfurt FSV                                   43.0

# %% [markdown]
# # Connecting to the DarkSky API

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/Users/ravimalde/.secret/dark_sky_api.json")
api_key = keys['api_key']
print(api_key)

latitude = 51.5074
longitude = 0.1278

time = 1577836800

url = "https://api.darksky.net/forecast/{}/{},{}".format(api_key, latitude, longitude, time)

r = requests.get(url)

print(r.text)
# Out:
# 350b719624c4cb7f832830d73fe87a4d
# {"latitude":51.5074,"longitude":0.1278,"timezone":"Europe/London","currently":{"time":1580315488,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","nearestStormDistance":47,"nearestStormBearing":333,"precipIntensity":0,"precipProbability":0,"temperature":47.51,"apparentTemperature":42.45,"dewPoint":38.12,"humidity":0.7,"pressure":1010.8,"windSpeed":11.5,"windGust":25.35,"windBearing":244,"cloudCover":0.75,"uvIndex":0,"visibility":10,"ozone":334},"minutely":{"summary":"Mostly cloudy for the hour.","icon":"partly-cloudy-day","data":[{"time":1580315460,"precipIntensity":0,"precipProbability":0},{"time":1580315520,"precipIntensity":0,"precipProbability":0},{"time":1580315580,"precipIntensity":0,"precipProbability":0},{"time":1580315640,"precipIntensity":0,"precipProbability":0},{"time":1580315700,"precipIntensity":0,"precipProbability":0},{"time":1580315760,"precipIntensity":0,"precipProbability":0},{"time":1580315820,"precipIntensity":0,"precipProbability":0},{"time":1580315880,"precipIntensity":0,"precipProbability":0},{"time":1580315940,"precipIntensity":0,"precipProbability":0},{"time":1580316000,"precipIntensity":0,"precipProbability":0},{"time":1580316060,"precipIntensity":0,"precipProbability":0},{"time":1580316120,"precipIntensity":0,"precipProbability":0},{"time":1580316180,"precipIntensity":0,"precipProbability":0},{"time":1580316240,"precipIntensity":0,"precipProbability":0},{"time":1580316300,"precipIntensity":0,"precipProbability":0},{"time":1580316360,"precipIntensity":0,"precipProbability":0},{"time":1580316420,"precipIntensity":0,"precipProbability":0},{"time":1580316480,"precipIntensity":0,"precipProbability":0},{"time":1580316540,"precipIntensity":0,"precipProbability":0},{"time":1580316600,"precipIntensity":0,"precipProbability":0},{"time":1580316660,"precipIntensity":0,"precipProbability":0},{"time":1580316720,"precipIntensity":0,"precipProbability":0},{"time":1580316780,"precipIntensity":0,"precipProbability":0},{"time":1580316840,"precipIntensity":0,"precipProbability":0},{"time":1580316900,"precipIntensity":0,"precipProbability":0},{"time":1580316960,"precipIntensity":0,"precipProbability":0},{"time":1580317020,"precipIntensity":0,"precipProbability":0},{"time":1580317080,"precipIntensity":0,"precipProbability":0},{"time":1580317140,"precipIntensity":0,"precipProbability":0},{"time":1580317200,"precipIntensity":0,"precipProbability":0},{"time":1580317260,"precipIntensity":0,"precipProbability":0},{"time":1580317320,"precipIntensity":0,"precipProbability":0},{"time":1580317380,"precipIntensity":0,"precipProbability":0},{"time":1580317440,"precipIntensity":0,"precipProbability":0},{"time":1580317500,"precipIntensity":0,"precipProbability":0},{"time":1580317560,"precipIntensity":0,"precipProbability":0},{"time":1580317620,"precipIntensity":0,"precipProbability":0},{"time":1580317680,"precipIntensity":0,"precipProbability":0},{"time":1580317740,"precipIntensity":0,"precipProbability":0},{"time":1580317800,"precipIntensity":0,"precipProbability":0},{"time":1580317860,"precipIntensity":0,"precipProbability":0},{"time":1580317920,"precipIntensity":0,"precipProbability":0},{"time":1580317980,"precipIntensity":0,"precipProbability":0},{"time":1580318040,"precipIntensity":0,"precipProbability":0},{"time":1580318100,"precipIntensity":0,"precipProbability":0},{"time":1580318160,"precipIntensity":0,"precipProbability":0},{"time":1580318220,"precipIntensity":0,"precipProbability":0},{"time":1580318280,"precipIntensity":0,"precipProbability":0},{"time":1580318340,"precipIntensity":0,"precipProbability":0},{"time":1580318400,"precipIntensity":0,"precipProbability":0},{"time":1580318460,"precipIntensity":0,"precipProbability":0},{"time":1580318520,"precipIntensity":0,"precipProbability":0},{"time":1580318580,"precipIntensity":0,"precipProbability":0},{"time":1580318640,"precipIntensity":0,"precipProbability":0},{"time":1580318700,"precipIntensity":0,"precipProbability":0},{"time":1580318760,"precipIntensity":0,"precipProb ...

# %%
r.json().keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
r.json()['currently']
# Out:
# {'time': 1580313634,
#  'summary': 'Mostly Cloudy',
#  'icon': 'partly-cloudy-day',
#  'nearestStormDistance': 37,
#  'nearestStormBearing': 290,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 48.13,
#  'apparentTemperature': 43.19,
#  'dewPoint': 37.81,
#  'humidity': 0.67,
#  'pressure': 1010.8,
#  'windSpeed': 11.61,
#  'windGust': 25.2,
#  'windBearing': 248,
#  'cloudCover': 0.78,
#  'uvIndex': 0,
#  'visibility': 10,
#  'ozone': 336.5}
